# %%
import numpy as np

# %%
filePath = "../data/mfcc/train.ark"

# %%
with open(filePath) as f:
    train_data = np.frombuffer(f.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-43b34355c4ca> in <module>()
#       1 with open(filePath) as f:
# ----> 2     train_data = np.frombuffer(f.read())
#
# AttributeError: 'str' object has no attribute '__buffer__'

# %%
with open(filePath) as f:
    train_data = np.frombuffer(f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-06a6cb2ccf2c> in <module>()
#       1 with open(filePath) as f:
# ----> 2     train_data = np.frombuffer(f)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute '__buffer__'

# %%
dt = np.dtype([("id", str), ("feature", (float, 39))])

# %%
dt
# Out:
# dtype([('id', '<U'), ('feature', '<f8', (39,))])

# %%
dt = np.dtype([("id", str), ("feature", (np.float32, 39))])

# %%
dt
# Out:
# dtype([('id', '<U'), ('feature', '<f4', (39,))])

# %%
data = np.fromfile(filePath, dtype=dt)

# %%
data
# Out:
# array([ ('', [  4.43686342e+27,   1.83886553e+25,   1.07800568e-08,   3.72978057e-08,   6.67499535e-07,   9.10742315e-12,   6.33707475e-10,   4.39213618e-05,   6.44563514e-10,   4.24226343e-08,   9.10742402e-12,   2.64019604e-06,   1.68766604e-07,   2.57825405e-09,   4.22468220e-05,   9.10609348e-12,   1.76601825e-04,   4.41579323e-05,   4.18803880e-11,   1.72470052e-07,   4.07285039e-11,   2.72995112e-06,   2.38710800e-06,   1.07405194e-05,   1.56860638e-19,   1.01402238e-08,   2.75952061e-06,   4.09673406e-11,   1.66885769e-07,   9.10631900e-12,   4.15334398e-05,   2.69484390e-09,   1.03130162e-08,   1.68766491e-07,   9.10654278e-12,   6.74949661e-07,   4.26527755e-08,   4.00463586e-11,   4.19533599e-08]),
# ...

# %%
data = np.genfromtxt(filePath, dtype=dt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f291bbea6dea> in <module>()
# ----> 1 data = np.genfromtxt(filePath, dtype=dt)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
filePath
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b9aa3a69a933> in <module>()
# ----> 1 filePath
#
# NameError: name 'filePath' is not defined

# %%
filePath = "../data/mfcc/train.ark"

# %%
dt = np.dtype([("id", str), ("feature", (np.float32, 39))])

# %%
data = np.genfromtxt(filePath, dtype=dt)

# %%
data
# Out:
# array([ ('', [  3.83507996e+01,  -3.10488796e+01,  -1.04631796e+01,  -9.16665363e+00,  -1.12183199e+01,  -1.99869800e+00,   1.85094795e+01,   3.44764209e+00,   6.24780893e+00,  -5.24096012e+00,  -4.61347294e+00,  -1.48209105e+01,  -1.26549397e+01,  -5.59173107e-01,   5.04302979e-01,   1.61000001e+00,   3.28951806e-01,   3.23263597e+00,   1.16574502e+00,  -6.02618313e+00,  -3.91766697e-01,   1.38175797e+00,   4.44541311e+00,   2.94172001e+00,   2.51154709e+00,   2.56285000e+00,  -3.26184690e-01,  -1.66807696e-01,  -1.31458893e-01,  -4.11973596e-01,   2.51379102e-01,  -1.99842509e-02,  -1.28335202e+00,   2.17252806e-01,   4.12052006e-01,   6.22866392e-01,   7.54879177e-01,   1.06367695e+00,   7.84817278e-01]),
# ...

# %%
dt
# Out:
# dtype([('id', '<U'), ('feature', '<f4', (39,))])

# %%
dt = np.dtype([("id", np.str_), ("feature", (np.float32, 39))])

# %%
data = np.genfromtxt(filePath, dtype=dt)

# %%
data
# Out:
# array([ ('', [  3.83507996e+01,  -3.10488796e+01,  -1.04631796e+01,  -9.16665363e+00,  -1.12183199e+01,  -1.99869800e+00,   1.85094795e+01,   3.44764209e+00,   6.24780893e+00,  -5.24096012e+00,  -4.61347294e+00,  -1.48209105e+01,  -1.26549397e+01,  -5.59173107e-01,   5.04302979e-01,   1.61000001e+00,   3.28951806e-01,   3.23263597e+00,   1.16574502e+00,  -6.02618313e+00,  -3.91766697e-01,   1.38175797e+00,   4.44541311e+00,   2.94172001e+00,   2.51154709e+00,   2.56285000e+00,  -3.26184690e-01,  -1.66807696e-01,  -1.31458893e-01,  -4.11973596e-01,   2.51379102e-01,  -1.99842509e-02,  -1.28335202e+00,   2.17252806e-01,   4.12052006e-01,   6.22866392e-01,   7.54879177e-01,   1.06367695e+00,   7.84817278e-01]),
# ...

# %%
data = np.genfromtxt(filePath, dtype=dt, delimiter=' ')

# %%
data
# Out:
# array([ ('', [  3.83507996e+01,  -3.10488796e+01,  -1.04631796e+01,  -9.16665363e+00,  -1.12183199e+01,  -1.99869800e+00,   1.85094795e+01,   3.44764209e+00,   6.24780893e+00,  -5.24096012e+00,  -4.61347294e+00,  -1.48209105e+01,  -1.26549397e+01,  -5.59173107e-01,   5.04302979e-01,   1.61000001e+00,   3.28951806e-01,   3.23263597e+00,   1.16574502e+00,  -6.02618313e+00,  -3.91766697e-01,   1.38175797e+00,   4.44541311e+00,   2.94172001e+00,   2.51154709e+00,   2.56285000e+00,  -3.26184690e-01,  -1.66807696e-01,  -1.31458893e-01,  -4.11973596e-01,   2.51379102e-01,  -1.99842509e-02,  -1.28335202e+00,   2.17252806e-01,   4.12052006e-01,   6.22866392e-01,   7.54879177e-01,   1.06367695e+00,   7.84817278e-01]),
# ...

# %%
dt = np.dtype([("id", 'S10'), ("feature", (np.float32, 39))])

# %%
data = np.genfromtxt(filePath, dtype=dt, delimiter=' ')

# %%
data
# Out:
# array([ (b'faem0_si13', [  3.83507996e+01,  -3.10488796e+01,  -1.04631796e+01,  -9.16665363e+00,  -1.12183199e+01,  -1.99869800e+00,   1.85094795e+01,   3.44764209e+00,   6.24780893e+00,  -5.24096012e+00,  -4.61347294e+00,  -1.48209105e+01,  -1.26549397e+01,  -5.59173107e-01,   5.04302979e-01,   1.61000001e+00,   3.28951806e-01,   3.23263597e+00,   1.16574502e+00,  -6.02618313e+00,  -3.91766697e-01,   1.38175797e+00,   4.44541311e+00,   2.94172001e+00,   2.51154709e+00,   2.56285000e+00,  -3.26184690e-01,  -1.66807696e-01,  -1.31458893e-01,  -4.11973596e-01,   2.51379102e-01,  -1.99842509e-02,  -1.28335202e+00,   2.17252806e-01,   4.12052006e-01,   6.22866392e-01,   7.54879177e-01,   1.06367695e+00,   7.84817278e-01]),
# ...

# %%
dt = np.dtype([("id", 'S20'), ("feature", (np.float32, 39))])

# %%
data = np.genfromtxt(filePath, dtype=dt, delimiter=' ')

# %%
data
# Out:
# array([ (b'faem0_si1392_1', [  3.83507996e+01,  -3.10488796e+01,  -1.04631796e+01,  -9.16665363e+00,  -1.12183199e+01,  -1.99869800e+00,   1.85094795e+01,   3.44764209e+00,   6.24780893e+00,  -5.24096012e+00,  -4.61347294e+00,  -1.48209105e+01,  -1.26549397e+01,  -5.59173107e-01,   5.04302979e-01,   1.61000001e+00,   3.28951806e-01,   3.23263597e+00,   1.16574502e+00,  -6.02618313e+00,  -3.91766697e-01,   1.38175797e+00,   4.44541311e+00,   2.94172001e+00,   2.51154709e+00,   2.56285000e+00,  -3.26184690e-01,  -1.66807696e-01,  -1.31458893e-01,  -4.11973596e-01,   2.51379102e-01,  -1.99842509e-02,  -1.28335202e+00,   2.17252806e-01,   4.12052006e-01,   6.22866392e-01,   7.54879177e-01,   1.06367695e+00,   7.84817278e-01]),
# ...

# %%
data.shape
# Out:
# (1124823,)

# %%
data[0]
# Out:
# (b'faem0_si1392_1', [  3.83507996e+01,  -3.10488796e+01,  -1.04631796e+01,  -9.16665363e+00,  -1.12183199e+01,  -1.99869800e+00,   1.85094795e+01,   3.44764209e+00,   6.24780893e+00,  -5.24096012e+00,  -4.61347294e+00,  -1.48209105e+01,  -1.26549397e+01,  -5.59173107e-01,   5.04302979e-01,   1.61000001e+00,   3.28951806e-01,   3.23263597e+00,   1.16574502e+00,  -6.02618313e+00,  -3.91766697e-01,   1.38175797e+00,   4.44541311e+00,   2.94172001e+00,   2.51154709e+00,   2.56285000e+00,  -3.26184690e-01,  -1.66807696e-01,  -1.31458893e-01,  -4.11973596e-01,   2.51379102e-01,  -1.99842509e-02,  -1.28335202e+00,   2.17252806e-01,   4.12052006e-01,   6.22866392e-01,   7.54879177e-01,   1.06367695e+00,   7.84817278e-01])

# %%
dt = np.dtype(("id", 'S20'), ("feature", (np.float32, 39)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-1b7818294afb> in <module>()
# ----> 1 dt = np.dtype(("id", 'S20'), ("feature", (np.float32, 39)))
#
# TypeError: data type "id" not understood

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>()
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-64156d691fe5> in <module>()
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
